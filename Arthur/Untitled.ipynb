# %% [markdown]
# # Introduction to Jupyter Notebooks
#
# In general, google is your friend. Here are some keywords that might help you with searching for things:
#
# - "Markdown cheat sheet"
# - "How to change cells in jupyter notebboks from code to markdown"
# - "Why can Jupyter notebook not find python package insert name here"
# - "How to read in data from a text file with astropy"
# - "How to use plt.plot from matplotlib"
# - "Documentation for some python package name"
#
# Last note: you can't break it, it's only software. So try, google, try, google, and try again

# %%
my_variable = "hello world"

# %%
print(my_variable)
# Out:
# hello world

# %% [markdown]
# # Example input for a markdown heading
#
# ## This is a sub-heading.
#
# Ipsum lorum
#
# Having trouble with markdown? -
# https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet
#
# ![](https://scitechdaily.com/images/James-Webb-Space-Telescope-Cold-Side-scaled.jpg)

# %%
# Collect my import statements here
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate 1000 random coordinates for x and for y, then multiply them by 100
x = np.random.random(1000) * 100
y = np.random.random(1000) * 100

# %%
plt.plot(x,y, ".")

# %%
# Generate 1000 random coordinates according to a normal (gaussian) distribution for x and for y
x = np.random.normal(0, 1, 1000)
y = np.random.normal(0, 1, 1000)

# %%
plt.plot(x,y, ".")
plt.savefig("gaussian_cluster.png")

# %%
# Generate 1000 random integer (ganzzahl) coordinates 
n = 1000
x = np.random.randint(low=0, high=100, size=n)
y = np.random.randint(low=0, high=100, size=n)

# Make an empty image with dimensions 100x100
image = np.zeros(shape=(100,100))

# Add a "star" for each coordinate contained in the lists of coordinates (x and y)
for i in range(len(x)):
    image[x[i],y[i]] += 1

plt.imshow(image)
plt.colorbar()
